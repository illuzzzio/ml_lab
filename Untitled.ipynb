# %%
import pandas as pd 
df = pd.read_csv("solubility_data_file.csv")
df
# Out:
#     time  marks
# 0      2     30
# 1      4     67
# 2      5     70
# 3      4     65
# 4      4     66
# 5      6     75
# 6      7     80
# 7      8     81
# 8      1     16
# 9      2     29
# 10     4     66

# %%
y = df["marks"]
y
# Out:
# 0     30
# 1     67
# 2     70
# 3     65
# 4     66
# 5     75
# 6     80
# 7     81
# 8     16
# 9     29
# 10    66
# Name: marks, dtype: int64

# %%
x = df.drop("marks", axis=1)  #axis = 1 , means drop the column (means vertical section), axis = 0 means drop the horizontal row , so here we need to dro pthe column of logS
x
# Out:
#     time
# 0      2
# 1      4
# 2      5
# 3      4
# 4      4
# 5      6
# 6      7
# 7      8
# 8      1
# 9      2
# 10     4

# %%
from sklearn.linear_model import LinearRegression

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
X_train
# Out:
#     time
# 10     4
# 2      5
# 1      4
# 8      1
# 4      4
# 7      8
# 3      4
# 6      7

# %%
X_test
# Out:
#    time
# 5     6
# 0     2
# 9     2

# %%
from sklearn.linear_model import LinearRegression
LR = LinearRegression()
LR.fit(X_train,y_train)
LinearRegression()
# Out:
# LinearRegression()

# %%
y_LR_train_predict = LR.predict(X_train)
y_LR_test_predict  = LR.predict(X_test)

y_LR_train_predict
# Out:
# array([58.64705882, 67.01176471, 58.64705882, 33.55294118, 58.64705882,
#        92.10588235, 58.64705882, 83.74117647])

# %%
y_LR_test_predict
# Out:
# array([-3.12244349, -4.16385375, -2.48834741])

# %%
y_train
# Out:
# 10    66
# 2     70
# 1     67
# 8     16
# 4     66
# 7     81
# 3     65
# 6     80
# Name: marks, dtype: int64

# %%
y_LR_train_predict # it is the predicted values of y on the 80 percent of data trained earlier
# Out:
# array([58.64705882, 67.01176471, 58.64705882, 33.55294118, 58.64705882,
#        92.10588235, 58.64705882, 83.74117647])

# %%
#FINAL MODEL EVALUATION#

from sklearn.metrics import mean_squared_error, r2_score
#mean_squared_error (MSE):

 # Purpose: This function calculates the Mean Squared Error, which is a common metric to quantify the average squared difference between the actual (true) values and the predicted values from a regression model.

 #r2_score (R-squared or Coefficient of Determination):

#Purpose: This function calculates the R-squared score, which measures the proportion of the variance in the dependent variable that is predictable from the independent variable(s). In simpler terms, it indicates how well the regression model explains the variability in the target variable


#First lets do it for training models:
LR_train_mse = mean_squared_error(y_train, y_LR_train_predict) 
LR_train_r2 = r2_score(y_train, y_LR_train_predict)
# comparision of both for evaluation of the model 

#Now lets do this for testing models:
LR_test_mse = mean_squared_error(y_test,y_LR_test_predict)
LR_test_r2 = r2_score(y_test,y_LR_test_predict)

print("LR MSE (TRAIN): ",LR_train_mse)
print("LR r2 (TRAIN): ",LR_train_r2)
print("LR MSE (TEST): ",LR_test_mse)
print("LR r2 (TEST): ",LR_test_r2)

# Above i am printing our results 


LR_results = pd.DataFrame(["Linear Regression Model", LR_train_mse, LR_train_r2, LR_test_mse, LR_test_r2]).transpose()
LR_results.columns= ["Method","Training MSE","TrainingR2","Test MSE","Test R2"] # This we are doing to maek data more tidy 
LR_results
# Out:
# LR MSE (TRAIN):  84.0794117647059
# LR r2 (TRAIN):  0.7682865110906784
# LR MSE (TEST):  103.01254901960779
# LR r2 (TEST):  0.7761678075382737
#                     Method Training MSE TrainingR2    Test MSE   Test R2
# 0  Linear Regression Model    84.079412   0.768287  103.012549  0.776168

# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.cm import get_cmap

# Scatter plot
plt.scatter(y_train, y_LR_train_predict, alpha=0.5, color='blue')

# Fit regression line
z = np.polyfit(y_train, y_LR_train_predict, 1)
p = np.poly1d(z)

# Sort values for smooth regression line
y_train_sorted = np.sort(y_train)

# Plot regression line
plt.plot(
    y_train_sorted,
    p(y_train_sorted),
    color='red',
    linewidth=3,
    label="Linear Regression Line"
)

# Connect scatter points with different colored lines
cmap = get_cmap("rainbow")

# Sort points based on actual values for proper connection
sorted_indices = np.argsort(y_train)
x_sorted = np.array(y_train)[sorted_indices]
y_pred_sorted = np.array(y_LR_train_predict)[sorted_indices]

for i in range(len(x_sorted)-1):
    plt.plot(
        [x_sorted[i], x_sorted[i+1]],
        [y_pred_sorted[i], y_pred_sorted[i+1]],
        color=cmap(i / len(x_sorted)),
        linewidth=1.5
    )

# Equation of regression line
equation = f"y = {z[0]:.2f}x + {z[1]:.2f}"

# Display equation
plt.text(
    0.05, 0.95,
    equation,
    transform=plt.gca().transAxes,
    fontsize=12,
    color='red',
    bbox=dict(facecolor='white', alpha=0.7)
)

# Labels
plt.xlabel("Actual Marks")
plt.ylabel("Predicted Marks")
plt.title("Linear Regression - Training Predictions")

plt.legend()
plt.grid(True)
plt.show()
# Out:
# C:\Users\student\AppData\Local\Temp\ipykernel_1428\1436019068.py:25: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   cmap = get_cmap("rainbow")
